# %%
import pandas as pd
df = pd.read_csv("../data/Home_Guards_Strength_As_On-October_2022.csv")
#print(df.head())
# print(df.shape)
# print(df.dtypes)
# print(df.isnull().sum())
print(df)
# Out:
#     SL. NO. NAME OF THE DISTRICT  NUMBER  OF UNITS  ALLOTTED STRENGTH  \
# 0         1      Bengaluru North                18               1850
# 1         2      Bengaluru Rural                15               1650
# 2         3      Bengaluru South                15               1850
# 3         4            Bagalkote                23               1000
# 4         5             Belagavi                30               1350
# 5         6              Ballari                22               1500
# 6         7                Bidar                15               1000
# 7         8        Chikkmagaluru                20                800
# 8         9       Chamarajanagar                 9                700
# 9        10         Chithradurga                14                700
# 10       11      Chikkaballapura                 7                700
# 11       12              Dharwad                 8                800
# ...
